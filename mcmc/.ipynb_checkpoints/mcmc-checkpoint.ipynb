# %% [markdown]
# # Markov chains Monte Carlo

# %% [markdown]
# ## Quelques aspects techniques avant de commencer
#
# Il est très important de faire tourner la section ci-dessous, même si d'un point de vue pratique elle ne fait que préparer les instruments dont nous allons nous servir plus tard dans le document. Dans ce notebook, il est important d’exécuter `set.seed`, car nous allons effectuer une série d’opérations stochastiques qui peuvent légèrement varier à chaque exécution.  Ainsi, si nous voulons que le code produise exactement les mêmes résultats à chaque fois — pour garantir la reproductibilité — il est nécessaire de fixer la graine aléatoire avec `set.seed()`.

# %%
# library utilisée pour faire le graphique
# install.packages("ggplot2") # installation, à faire une seule fois
# install.packages("tidyverse2") # installation, à faire une seule fois
library(ggplot2) # chargement
library(tidyverse)
library(HDInterval)


set.seed(1234)
darkred <- "#8B0000"

# %% [markdown]
# ## La Vraisemblance marginale
#
# La vraisemblance marginale mesure à quel point le modèle complet (paramètres + données) explique bien les données observées, en tenant compte de toutes les valeurs possibles du paramètre, pondérées par leur probabilité a priori.
#
# Autrement dit, c’est une moyenne pondérée de la vraisemblance sur toutes les valeurs possibles de $\theta$, l'idée c'est d'avoir un metrique qui exprime à quel point un modèle décrit bien les données indépendament de la valeur que son paramètre peut prendre.
#
# Formellement cela se calcule comme une intégrale, donc dans notre cas il se formalise comme il suit:
#
# $$ P(x) = \int d\theta \  P(x \mid \theta) \cdot P(\theta) $$

# %% [markdown]
# ### Exemple de intégration numérique à la main
#
# Dans le chapitre sur les priors, nous avons calculé la distribution a posteriori en utilisant la loi Bêta et sa constante de normalisation.
# Ici, nous allons calculer la même distribution a posteriori en utilisant l'intégration numérique.
# Nous allons reprendre exactement le même exemple : dix personnes ont suivi le traitement, et trois d’entre elles ont eu une rechute à six mois.
# Nous utilisons un modèle basé sur une loi binomiale, avec un paramètre $\theta$ représentant la probabilité de rechute à estimer, et un prior défini par une loi Bêta avec $\alpha = \beta = 2$

# %%
# Données
k = 3
n = 10
# Hyperparamètres du prior
alpha = 2
beta = 2
# Espace des paramètres à explorer (variant de 0 à 1 avec des pas de 0,002)
p <- seq(0,1,.002)

# %% [markdown]
# À partir de cela, nous allons construire une fonction qui, pour chaque valeur du paramètre, multiplie la vraisemblance (calculée avec un modèle binomial) par le prior (défini à l’aide d’une loi Beta).
# Cette opération correspond au numérateur dans la formule de Bayes, c’est-à-dire la partie qui combine ce que nous savons avant (le prior) et ce que nous apprenons avec les données (la vraisemblance) et dans le code elle s'implément comme il suit:

# %%
# numérateur dans la forumle de bayse : vraisemblance * prior
numerator <- function(p) dbinom(k,n,p)*dbeta(p,alpha,beta)

# %% [markdown]
# Nous pouvons créer une representation graphique de cette distribution comme il suit:

# %%
# mettre le tout dans une dataframe
df <- data.frame(prob = p, num = numerator(p))

# faire le graphique
ggplot(df, aes(x = prob, y = num)) +
  geom_area(fill = "lightblue", alpha = 0.4) +
  geom_line(color = "darkblue", linewidth = 1.2) +
  annotate("text", x = max(df$prob)*0.8, y = max(df$num) * 0.9, 
           label = paste0("Aire sous la courbe = ", round(denominator,3)),
           size = 5, color = "black") +
  labs(
    x = expression(theta),
    y = "Vraisemblance x Prior"
  ) +
   theme_minimal(base_size = 18)
# Out:
# plot without title

# %% [markdown]
# Vous pouvez voir que cette distribution n'est pas une fonction de densité valide, car son intégrale ne correspond pas à 1. Pour obtenir une distribution a posteriori qui représente une fonction de densité valide, il nous faut cette fameuse constante de normalisation $P(D)$.
# Pour l'obtenir, nous devons d'abord calculer l'intégrale de cette distribution. Comme il s'agit d'une intégrale simple, nous pouvons faire appel à la fonction `integrate`, comme suit :

# %%
# denominateur (aire sous la curbe)
denominator <- integrate(numerator,0,1)$value

# %% [markdown]
# Ensuite, il suffit de diviser le numérateur (vraisemblance × prior) par la valeur de l'intégrale, comme suit :

# %%
# posterior
posterior <- numerator(p)/denominator

# %% [markdown]
# Si l'on fait une représentation graphique de cette distribution, on peut voir qu'il s'agit bien d'une fonction de densité valide, et que son intégrale est égale à 1 :

# %%
# mettre le tout dans une dataframe
df <- data.frame(prob = p, post = posterior)

# calcule de l'intégrale du posterior
post <-function(p) numerator(p)/denominator

aire_curbe <- integrate(post,0,1)$value


# faire le graphique
ggplot(df, aes(x = prob, y = post)) +
  geom_area(fill = "orange", alpha = 0.4) +
  geom_line(color = "darkred", linewidth = 1.2) +
  annotate("text", x = max(df$prob)*0.8, y = max(df$post) * 0.9, 
           label = paste0("Aire sous la curbe = ", round(aire_curbe,3)),
           size = 5, color = "black") +
  labs(
    x = expression(theta),
    y = "Vraisemblance x Prior / intégrale"
  ) +
   theme_minimal(base_size = 18)
# Out:
# plot without title

# %% [markdown]
# Comme confirmation, vous pouvez observer comment cette distribution correspond exactement à ce que nous avons calculé en utilisant la loi Bêta comme constante de normalisation dans le chapitre sur les priors.

# %%
# hyper paramètres de la distribution a priori
alpha_pr = 2
beta_pr  = 2

# data
k = 3
n = 10

# hyper paramètres de la distribution a posteriori
alpha <- alpha_pr + k
beta  <- beta_pr + n - k

print(alpha)
print(beta)

# Create a grid of values between 0 and 1
x <- seq(0.0001, 0.9999, by = 0.0001)
y <- dbeta(x, alpha, beta)

#
samples <- rbeta(10000, alpha, beta)

# Data for plotting
df <- data.frame(x = x, y = y)

# Create the plot
ggplot(df, aes(x = x, y = y)) +
  geom_line(color = "darkred", linewidth = 1.2) +
  labs(title = "",
       x = expression(theta),
       y = "Densité") +
  theme_minimal(base_size = 18)
# Out:
# [1] 5
# [1] 9
# plot without title

# %% [markdown]
# ## L'approximation de la distribution à posteriori par MCMC
#
# Obtenir la constante de normalisation par le calcule de l'intégrale n'est pas toujour possible, en particulier cela est compliqué (voir impossible) dans le cas des intégrales multiples. Cela a historiquement representé l'obstacle majeur dans l'implémentation des méthodes Baysien, effectivement même dans le cas d'un régression linaire simple (ce qui represente un des modèles les plus simples utilisée en psychologie expérimentale), nous avons déjà 3 paramètres à estimer ($\beta_0$,$\beta_1$, $\sigma$), ce qui nécessite déjà d'un calcule d'intégrale multidimentionnelle.
#
# Le boost à l'application des statistiques baysienne est arrivé grace au developpement des dits **Markov Chains Monte Carlo**, abbreviée comme MCMC.
#
# L'idée clée des méthode *Monte Carlo*, c'est d'utiliser le hasard pour reussir à ressoudre des problèmes complexes qui ne peuvent pas être calculés. Pour comprendre cette idée vous pouvez imaginer l'example suivant: après une forte pluie votre jardin est couvert par des grandes flaques de bouts. Pour écrire à votre assurance, vous voulez quantifier la proportion de votre jardin qui coverte par le bout, mais cela est très compliqué à calculer. On peut alors procèder à une éstimation de la manière suivante: On jette $1000$ petits cailloux partout dans le jardin et on compte combien de cailloux tombent dans le bout. Si par example $750$ cailloux sont à l'ombre, vous pouvez en conclure que environs  $75%$ du jardin est couver par du bout. Cela c'est l'idée au cours des méthod Monte Carlo: utiliser des tirages aléatoires pour estimer une quantité difficile à calculer autrement.
#
# La méthode de Monte Carlo a été développée pendant la Seconde Guerre mondiale, dans le cadre du projet Manhattan (dans le laboratoire Los Alamos) qui visait à construire la première bombe atomique. L’idée vient du physicien Stanislaw Ulam qui l’aide de John von Neumann ont imaginé une méthode consistant à faire de nombreux tirages aléatoires pour simuler des phénomènes physiques comme la diffusion des neutrons. Le nom "Monte Carlo" vient du célèbre casino de Monaco. Après la guerre, les chercheurs de Los Alamos ont continué à s’intéresser aux systèmes physiques complexe et le dévelopement des méthodes MCMC prend un détour important en 1953 avec la publication d’un article écrit par Nicholas Metropolis, **Arianna Rosenbluth**, Marshall Rosenbluth, Augusta Teller et Edward Teller. Cet article présente ce qu’on appelle aujourd’hui l’algorithme de Metropolis, une version de la méthode de Monte Carlo qui utilise de chaines de Markov à la place que des tirages complétament aléatoires. Cet algorithme est devenu la base du MCMC (Monte Carlo par Chaînes de Markov), la méthode que on utilise aujourd’hui dans les statistiques bayésiennes pour l'approximation de la distribution à posteriori.
#
# Bien que l’algorithme porte le nom de Metropolis, c’est en réalité Arianna Rosenbluth qui a écrit le code informatique et réalisé les premières simulations. Elle a joué un rôle central dans la mise en œuvre pratique de l’algorithme, en programmant les calculs sur les premiers ordinateurs de Los Alamos, à une époque où la programmation demandait une grande rigueur et une expertise technique exceptionnelle.
#
#
# Les MCMC permettend d'approximer la distribution à posteriori sans devoir passer par l'intégration numérique. Ces méthodes utilisent des méthodes stochatisques (i.e., marche alétoire) pour une serie de valeur de paramètres, plus de paramètres on généres, plus la distribution de ces paramètres converges vers une distribution d'equilibre, cette distribution d'equilibre correspond à la distribution à posteriori que on cherche à estimer.
#
# Pour générer ces valeurs, dans les MCMC on utilise marche alétoire (*random walk*) our explorer l'espace des paramètres (par exemple, les valeurs possibles de $\theta$). Une marche aléatoire est un processus stochastique (c’est-à-dire basé sur le hasard) dans lequel on se déplace pas à pas, à chaque étape en choisissant une nouvelle position au hasard, autour de la position précédente.
#
# Cette marche alétoire est dit *Markovienne*, parce que chaque pas au moment ($t$) dépend du pas prédedant ($t-1$) et **non pas des autres pas fait dans le passé** (e.g., $t-2$, $t-3$, $t-4$, etc).
#
# On utilise le terme *Chaine* qui souligne aussi que chaque pas (i.e., chaque valeur générée par l'algorithm) dépend du pas précédant: les valeurs générées sont liées les unes aux autres, formant une suite ordonnée d'états où chaque état dépend du précédent.
#
#
# Dans l'algorithm de Metropolis nous pouvons distinguer 4 étapes:
#
# - **1) Définition l'état de départ:**  Nous allons toujours partir d'une valeur possible du paramètre dont on cherche d'estimer la distribution a posteriori. Cela est est typiquement définit comme le point de départ de la chaine de Markov ou la valeur initale.
#
# - **2) Définir le prochain état possible:** Nous proposon de nous éloigner de la valeur actuelle du paramètre (*valeur actuelle*) vers oune nouvelle valeur du paramètre. Nous ajoutons à cette valeur actuelle une valeur aléatoire provenant, disons, d'une distribution normale avec une certaine variance. Nous appelons cela l'emplacement candidat (*valeur candidat*).
#
# - **3) Calculer le ratio entre le postriori de valeur currente et la valeur candidat:** Nous allons caluler le ratio dans la manière suivante: $$R = \frac{\text{posterior(valeur candidat)}}{\text{posterior(valeur actuelle)}}$$ Cette étape est celle qui est particulièrement utile dans le calcule de la distribution à posteriori parce que la probabilité des données ($P(D)$) apparait de manière identitique au numérateur et dénumerateur du calcule du ratio $R$ et donc s'annulle. Le calcule du ratio $R$ dans le MCMC ce fait donc sans passer par le calcule d'une intégrale. Plus la valeur de $R$ est grande plus la valeur candidate a une plus grande vraisemblance par rapport à la valeur currante.
#
# - **4) Décide si bouger vers la valeur candidat ou rester:**  Nous tirons au hasard un numero $X$ entre 0 et 1 (*random spin*), si ce numero est plus grand que le ratio $R$ alors on bouge ver la valeur candidat autrement on reste sur la valeur actuelle
#
#
#
#
# ## Exemple de l'algorithme de Metropolis avec le code en R
#
#
# Nous pouvons reprendre exactement le même exemple pour illustrer le fonctionnement de l'algorithme de Metropolis et voir comment il fonctionne pas à pas en R. Le code ci-dessus est adapté du code du Dr Olivier Gimenez. Vous pouvez trouver plus d’informations sur ce thème sur son site (https://github.com/oliviergimenez/Bayesian_Workshop/tree/master), si vous souhaitez aller plus loin sur ce sujet: les explications sont d’excellente qualité et accompagnées de vidéos en français.
#
#
# ### Définir des données
#
# Ici, j’ai simplement modifié le code pour l’adapter à notre exemple de base. Tout d’abord, il faut définir les données que nous avons, comme il suit:

# %%
# Données
k <- 3
n <- 10

# %% [markdown]
# ### Définir les fonctions de vraisemblance, du prior et du posterior
#
# Nous allons maintenant définir les fonctions de vraisemblance, du prior et du posterior.
# Avant cela, nous devons faire une petite modification  par rapport à ce que nous avons vu jusqu’à présent.
#
# Nous allons travailler avec les logarithmes de la vraisemblance et du prior. Cette transformation permet de remplacer les opérations multiplicatives (souvent utilisées en probabilités) par des opérations additives, ce qui est plus stable numériquement et plus facile à implémenter en `R`. Concrètement cela signifie que nous allons modifer la formule de Bayes classique qui s’écrit normalement ainsi :
#
# $$
# P(\theta \mid D) = \frac{P(D \mid \theta) \cdot P(\theta)}{P(D)}
# $$
#
# En prenant le logarithme de chaque terme (comme le logarithme d’un produit est la somme des logarithmes), nous allons donc l'écrire comme il suit  :
#
# $$
# \log P(\theta \mid D) = \log P(D \mid \theta) + \log P(\theta) - \log P(D)
# $$
#
# Cette forme additive est particulièrement utile en programmation, parce que elle évite les erreurs d’arrondi dues à des très petits nombres multipliés. Dans le cas specifique de l'algorithm de Metropolis, cela simplifie les calculs dans la comparison des ratios (que on verra en suite dans les détails).
#
# Commencons par définir la fonction qui nous donnera le log de la vraisemblance, il s'agit toujour d'une binomiale (`dbinom`), mais cette fois on calcule le logarithme de la vraisemblance, en spécifiant `log = TRUE`

# %%
# log-likelihood function

loglikelihood <- function(x, p){
  dbinom(x = x, size = n, prob = p, log = TRUE)
}

# %% [markdown]
# Nous allons faire de même pour le prior.
# Il s'agit toujours d'une loi Bêta avec $ \alpha = \beta = 2 $, transformé en logarithme :

# %%
# prior density
logprior <- function(p){
  dbeta(p,2,2, log = TRUE)
}

# %% [markdown]
# Finalement  ous allons maintenant définir la fonction pour le posterior. Ici, vous pouvez remarquer que la probabilité des données `log(Pr(D))` est mise en commentaire dans le code.  Cela est possible parce que dans l’algorithme de Metropolis, nous allons plutôt comparer des ratios entre différentes valeurs du posterior. Comme vu auparavant, dans ces ratios la probabilité des données $P(D)$  apparaît à la fois au numérateur et au dénominateur, donc il s’annule automatiquement.  C’est un avantage majeur de cet algorithme (et des MCMC en général): il nous permet de éviter le calcul de l’intégrale.
#
# Ainsi, nous pouvons travailler avec le logarithme du poterior non normalisé, sans avoir à calculer l’évidence.

# %%
# posterior density function (log scale) 
 posterior <- function(x, p){
  loglikelihood(x, p) + logprior(p) # - log(Pr(data)) 
}

# %% [markdown]
# ### Définir la fonction qui propose la nouvelle valeur
#
# La fonction `move` est la fonction que on utilise pour proposer la valeur candidat.
# - la variable `away` decide de combien d'unite on se deplace
# - `logitx` transform la valeur du paramètre avec une logistic simplement pour y rajuter de la variance random à partir d'une distribution normale `rnorm` centrée en 0, ce qui veut dire qu’elle a autant de chances de tirer une valeur positive que négative. Concrètement cela nous permet de respecter une assumption de base de l'algorithm de metropolis qui est que la marche alétoire la direction (gauche ou droite) de chaque pas doit être: 50/50. Cette symétrie gauche/droite vient de la distribution normale centrée en 0 utilisée pour proposer de nouveaux candidats. Dans le code ci-dessous cela est implicite:  comme la distribution normale est symétrique autour de zéro, dans  $50 %$ de chances que le candidat proposé soit plus grand que la valeur actuelle (mouvement vers la droite) et dans le  $50 %$ de chances qu’il soit plus petit (mouvement vers la gauche).
# - la traformation `plogis`remet simplement la valeur sur son échelle initial  entre 0 et 1 (c'est la transformation inverse de la logistique).

# %%
# propose candidate value
move <- function(x, away = .2){ 
  logitx <- log(x / (1 - x))                      # transform x to logit scale
  logit_candidate <- logitx + rnorm(1, 0, away)   # add noise from normal distribution
  candidate <- plogis(logit_candidate)            # transform back to [0, 1] scale
  return(candidate)
}

# %% [markdown]
# ### Définition de de la marche alétoire
#
# Dans cette fonction `metropolis` nous allons définir de nombre de pas que nous allons fair `steps` et la valeur initiale du paramètre `inits`.
#
# A chaque pas (repété dans la boucle `for` on:
# - propose une nouvelle valeur candidat (avec la function `move`)
# - calcule la valeur a posteriori de la valeur candidate et la valeur actuelle (`pstart` et `pprev`)
# - calcule le log ratio (`logR`) avec une operation additive (et non pas multiplicative parce que le posterior et en log).
# - on transforme le log ratio avec exponotielle (`exp`) pour avoir une valeur entre 0 et 1.
# - on decide si accepter ou pas la nouvelle valeur en faison le *random spin*

# %%
metropolis <- function(steps = 100, inits = 0.5){
  
  # pre-alloc memory
  theta.post <- rep(NA, steps)
  
  # start
  theta.post[1] <- inits
  
  for (t in 2:steps){
    
    # propose candidate value for prob of success
    theta_star <- move(theta.post[t-1])
    
    # calculate ratio R
    pstar <- posterior(k, p = theta_star)  
    pprev <- posterior(k, p = theta.post[t-1])
    logR <- pstar - pprev
    R    <- exp(logR)
    
    # decide to accept candidate value or to keep current value
    accept <- rbinom(1, 1, prob = min(R, 1))
    theta.post[t] <- ifelse(accept == 1, theta_star, theta.post[t-1])
  }
  theta.post
}

# %% [markdown]
# ### Implementation l'algorithm de Metropolis
#
# Dans le code ci-dessus implémente l'algorithm de Metropolis, nous allons définir le numero de pas (`steps`) et la valeur initiale de la chaine (`inits`). Ici nous allons construire troi chaines (`chain1`, `chain2`, `chain3`) avec des trois point de départ différents (`0.2`,`0.5`,`0.7`), attention selon le nombre de pas cela peut prendre un petit momement. Dans ce code, vous pouvez tester quelle est l'impact du nombre de pas sur l'estimation de la distribution à posteriori.

# %%
steps <- 10000

chain1 <- metropolis(steps = steps, inits = 0.2)
chain2 <- metropolis(steps = steps, inits = 0.5)
chain3 <- metropolis(steps = steps, inits = 0.7)

median(chain1)
median(chain2)
median(chain3)
# Out:
# [1] 0.3237892
# [1] 0.3209544
# [1] 0.3256489

# %%
Ensuite en met les valeurs dans une dataframe pour faire facilement des graphiques.

# %%
df <- data.frame(iter = rep(1:steps, 3), 
                 value = c(chain1, chain2, chain3),
                 chain = c(rep("chain1", steps), 
                           rep("chain2", steps), 
                           rep("chain3", steps)))

# %%
Represnetation graphique des chaines

# %%
chain_plot <- df %>%
  mutate(posterior_mean = mean(value)) %>%
  ggplot(aes(x = iter, y = value, group = chain, color = chain)) +
  geom_line(size = 1, alpha = 0.7) + 
  geom_hline(aes(yintercept = posterior_mean), linetype = 2) + 
  labs(color = "", x = "Iteration", y = expression(theta)) +
  theme_minimal(base_size = 18)

chain_plot
# Out:
# plot without title

# %% [markdown]
# Et representation graphique des l'approximation des distribution a posteriori estimées

# %%
# histogram
histogram_mcmc <- df %>% 
  mutate(posterior_mean = median(value)) %>%
  ggplot(aes(x = value, fill = chain)) +
  geom_histogram(color = "white", bins = 20, alpha = 0.7, position = "identity") + 
  geom_vline(aes(xintercept = posterior_mean), linetype = 2) +
  labs(x = expression(theta), fill = "")+
  theme_minimal(base_size = 18)

histogram_mcmc
# Out:
# plot without title

# %% [markdown]
# Sur la base de cela nous pouvons aussi faire le graphique de la densité de probabilité comme il suit:

# %%
density_mcmc <- df %>% 
  mutate(posterior_mean = median(value)) %>%
  ggplot(aes(x = value)) +
  geom_density(fill = darkred, alpha = 0.01, color = darkred, linewidth = 1.2) +
  geom_vline(aes(xintercept = posterior_mean), linetype = 2) +
   labs(title = "",
       x = expression(theta),
       y = "Densité") +
  theme_minimal(base_size = 18)

density_mcmc
# Out:
# plot without title

# %% [markdown]
# Et nous pouvons calculer la valeur median et l'intervalle HDI de cette distribution à posteriori approximé par metropolis

# %%
posterior_median <- median(df$value)
posterior_hdi <- hdi(df$value, credMass = 0.95)

posterior_median
posterior_hdi
# Out:
# [1] 0.3234562
#      lower      upper
# 0.09839445 0.58885382
# attr(,"credMass")
# [1] 0.95
